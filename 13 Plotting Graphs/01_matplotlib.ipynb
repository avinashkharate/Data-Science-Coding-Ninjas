# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x=[1,2,3]
y=[2,4,6]

plt.scatter(x,y)
plt.show()

# %%
x=[1,2,3]
y=[2,4,6]

x2=[3,4,5]
y2=[2,4,6]

plt.plot(x2,y2,'r-.')

plt.plot(x,y,'g')
plt.show()

# %%
#  Plot a function X**3

# x= np.array([1,2,3,4])
x=np.arange(0,5,0.1)
y=x**3

plt.plot(x,y,'ro')
plt.show()

# %%
a = [3,4,5]
plt.plot(a)
plt.plot()
# Out:
# []
