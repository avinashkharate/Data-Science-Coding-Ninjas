# %% [markdown]
# Problem-5 : Terror Frequency
# Problem Statement :
# Find the frequency of the Casualty in Red Corridor states and in Jammu and Kashmir ?Here Frequency is (Total Casualty/Total Number of a year)
# Print frequency as integer value.
# Note:Red Corridor state includes Jharkhand, Odisha, Andhra Pradesh, and Chhattisgarh. Here Casualty=Killed +Wounded.Don't fill the nan value present in Killed and Wounded feature.

# %%
import pandas as pd
df = pd.read_csv("terrorismData.csv")
df.head()
# Out:
#    Year  Month  Day             Country    State                       Region  \
# 0  1970      7    2  Dominican Republic      NaN  Central America & Caribbean
# 1  1970      0    0              Mexico  Federal                North America
# 2  1970      1    0         Philippines   Tarlac               Southeast Asia
# 3  1970      1    0              Greece   Attica               Western Europe
# 4  1970      1    0               Japan  Fukouka                    East Asia
#
#             City   Latitude   Longitude                      AttackType  \
# 0  Santo Domingo  18.456792  -69.951164                   Assassination
# 1    Mexico city  19.371887  -99.086624     Hostage Taking (Kidnapping)
# 2        Unknown  15.478598  120.599741                   Assassination
# 3         Athens  37.997490   23.762728               Bombing/Explosion
# 4        Fukouka  33.580412  130.396361  Facility/Infrastructure Attack
#
#    Killed  Wounded                   Target Summary  \
# 0     1.0      0.0             Julio Guzman     NaN
# 1     0.0      0.0  Nadine Chaval, daughter     NaN
# 2     1.0      0.0                 Employee     NaN
# 3     NaN      NaN             U.S. Embassy     NaN
# 4     NaN      NaN           U.S. Consulate     NaN
#
#                                 Group                  Target_type Weapon_type
# 0                              MANO-D  Private Citizens & Property     Unknown
# 1  23rd of September Communist League      Government (Diplomatic)     Unknown
# 2                             Unknown          Journalists & Media     Unknown
# 3                             Unknown      Government (Diplomatic)  Explosives
# 4                             Unknown      Government (Diplomatic)  Incendiary

# %%
df = df[df.Country == 'India']
df['Casualty'] = df['Killed'] + df['Wounded']

df.head()
# Out:
#       Year  Month  Day Country        State      Region        City  \
# 1186  1972      2   22   India        Delhi  South Asia   New Delhi
# 2764  1975      1    2   India        Bihar  South Asia  Samastipur
# 3857  1976      5   26   India        Delhi  South Asia   New Delhi
# 5327  1977      9   28   India  Maharashtra  South Asia      Bombay
# 7337  1979      1   13   India        Assam  South Asia     Unknown
#
#        Latitude  Longitude         AttackType  Killed  Wounded  \
# 1186  28.585836  77.153336          Hijacking     0.0      0.0
# 2764  25.863042  85.781004  Bombing/Explosion     4.0      0.0
# 3857  28.585836  77.153336  Bombing/Explosion     0.0      0.0
# 5327  19.075984  72.877656          Hijacking     0.0      0.0
# 7337  26.200605  92.937574      Armed Assault     NaN      NaN
#
#                                      Target  \
# 1186                                  B-747
# 2764  Lalit Narayan Mishra and a legislator
# 3857                      New Delhi airport
# 5327                                   DC-8
# 7337                                 patrol
#
#                                                 Summary  \
# 1186                                                NaN
# 2764  1/2/1975: The Indian Railway Minister, Lalit N...
# 3857                                                NaN
# 5327                                                NaN
# 7337                                                NaN
#
#                         Group           Target_type Weapon_type  Casualty
# 1186             Palestinians   Airports & Aircraft  Explosives       0.0
# 2764             Ananda Marga  Government (General)  Explosives       4.0
# 3857                  Unknown   Airports & Aircraft  Explosives       0.0
# 5327  Japanese Red Army (JRA)   Airports & Aircraft    Firearms       0.0
# 7337              Naga People                Police    Firearms       NaN

# %%
df_jk = df[df.State=='Jammu and Kashmir']
df_jk.head(1)
# Out:
#        Year  Month  Day Country              State      Region   City  \
# 21744  1984      4   17   India  Jammu and Kashmir  South Asia  Bhela
#
#         Latitude  Longitude     AttackType  Killed  Wounded  \
# 21744  33.315527  74.622476  Assassination     2.0      0.0
#
#                                                Target Summary  \
# 21744  Gurbachan Singh Sandhar (Sikh lawyer) and wife     NaN
#
#                  Group                  Target_type Weapon_type  Casualty
# 21744  Sikh Extremists  Private Citizens & Property     Unknown       2.0

# %%
df_red = df[(df.State == 'Jharkhand') | (df.State == 'Odisha') | (df.State == 'Andhra Pradesh') | (df.State == 'Chhattisgarh')]
df_red.head(1)
# Out:
#       Year  Month  Day Country           State      Region    City   Latitude  \
# 9053  1979      8    8   India  Andhra Pradesh  South Asia  Amapur  16.435329
#
#       Longitude AttackType  Killed  Wounded Target Summary  \
# 9053  77.831725    Unknown     1.0      1.0   town     NaN
#
#                     Group                  Target_type Weapon_type  Casualty
# 9053  Mizo National Front  Private Citizens & Property     Unknown       2.0

# %%
years = len(set(df['Year']))
years
# Out:
# 42

# %%
print(df_jk['Casualty'].sum() // years)
print(df_red['Casualty'].sum() // years)
# Out:
# 292.0
# 129.0
